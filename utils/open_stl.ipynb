# %%
import os
os.chdir('/home/victorhuang/projects/gtx/')

# %%
import open3d as o3d
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import numpy as np

# %%
mesh = o3d.io.read_triangle_mesh("data/Segmentation_T7.stl")

# %%
vertices = np.asarray(mesh.vertices)
triangles = np.asarray(mesh.triangles)

# %%
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111, projection="3d")
ax.add_collection3d(Poly3DCollection(vertices[triangles], alpha=0.3))
ax.scatter(vertices[:, 0], vertices[:, 1], vertices[:, 2], s=1)
plt.show()
